# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
import os

warnings.filterwarnings("ignore")

# %matplotlib inline
pd.set_option('display.max_columns',50)

# %%
os.chdir("../")
os.getcwd()
# Out:
# 'd:\\Bala\\Project_Inprogress\\Finance'

# %%
df = pd.read_parquet('input_file.parquet')
df.head()
# Out:
#   Date received                                            Product  \
# 0    2023-03-27  Credit reporting, credit repair services, or o...
# 1    2024-05-27  Credit reporting or other personal consumer re...
# 2    2023-06-13  Credit reporting, credit repair services, or o...
# 3    2024-01-01  Credit reporting or other personal consumer re...
# 4    2020-07-18                        Credit card or prepaid card
#
#          Sub-product                                              Issue  \
# 0   Credit reporting  Problem with a credit reporting company's inve...
# 1   Credit reporting                        Improper use of your report
# 2   Credit reporting  Problem with a credit reporting company's inve...
# 3   Credit reporting               Incorrect information on your report
# 4  Store credit card                              Getting a credit card
#
#                                            Sub-issue  \
# 0  Their investigation did not fix an error on yo...
# 1      Reporting company used your report improperly
# 2  Their investigation did not fix an error on yo...
# 3                Information belongs to someone else
# 4                                 Application denied
#
#                         Consumer complaint narrative  \
# 0                                               None
# 1  In accordance with the Fair Credit Reporting a...
# 2                                               None
# 3  Hello, My name is XXXX XXXX. I just turned XXX...
# 4  Obtaining credit should be based on legitimate...
#
#                              Company public response  \
# 0                                               None
# 1                             credit repair services
# 2  Company has responded to the consumer and the ...
# 3                                               None
# 4                                   virtual currency
#
#                                 Company             State  \
# 0                         EQUIFAX, INC.                GA
# 1   or other personal consumer reports"  Credit reporting
# 2   Experian Information Solutions Inc.                NM
# 3                         EQUIFAX, INC.                AR
# 4                     or money service"  Virtual currency
#
#                       ZIP code                                           Tags  \
# 0                        30291                                           None
# 1  Improper use of your report  Reporting company used your report improperly
# 2                        88007                                           None
# 3                        720XX                                           None
# 4        Other service problem                                           None
#
#                           Consumer consent provided? Submitted via  \
# 0                               Consent not provided           Web
# 1  My name is XXXX XXXX this complaint is not mad...          None
# 2                               Consent not provided           Web
# 3                                   Consent provided           Web
# 4                                               None          None
#
#   Date sent to company Company response to consumer Timely response?  \
# 0           2023-03-27      Closed with explanation              Yes
# 1        EQUIFAX, INC.                           LA            71301
# 2           2023-06-13      Closed with explanation              Yes
# 3           2024-01-01      Closed with explanation              Yes
# 4        PNC Bank N.A.                           GA            30340
#
#   Consumer disputed?          Complaint ID
# 0               None               6751274
# 1               None      Consent provided
# 2               None               7103923
# 3               None               8088111
# 4               None  Consent not provided

# %%
df.shape
# Out:
# (250000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date received                 250000 non-null  object
#  1   Product                       250000 non-null  object
#  2   Sub-product                   239715 non-null  object
#  3   Issue                         249999 non-null  object
#  4   Sub-issue                     218267 non-null  object
#  5   Consumer complaint narrative  80098 non-null   object
#  6   Company public response       131311 non-null  object
#  7   Company                       247256 non-null  object
#  8   State                         244166 non-null  object
#  9   ZIP code                      237929 non-null  object
#  10  Tags                          40183 non-null   object
#  11  Consumer consent provided?    187011 non-null  object
#  12  Submitted via                 240695 non-null  object
#  13  Date sent to company          245526 non-null  object
#  14  Company response to consumer  244823 non-null  object
#  15  Timely response?              237994 non-null  object
#  16  Consumer disputed?            45915 non-null   object
#  17  Complaint ID                  250000 non-null  object
# dtypes: object(18)
# memory usage: 34.3+ MB

# %%
df.describe().T
# Out:
#                                count  unique  \
# Date received                 250000    4649
# Product                       250000      20
# Sub-product                   239715      85
# Issue                         249999     171
# Sub-issue                     218267     259
# Consumer complaint narrative   80098   72076
# Company public response       131311    4306
# Company                       247256    6081
# State                         244166    6600
# ZIP code                      237929   19420
# Tags                           40183    2183
# Consumer consent provided?    187011    7415
# Submitted via                 240695    3533
# Date sent to company          245526    6756
# Company response to consumer  244823    1918
# Timely response?              237994    6161
# Consumer disputed?             45915    8375
# Complaint ID                  250000  222312
#
#                                                                             top  \
# Date received                                                        2024-08-28
# Product                       Credit reporting, credit repair services, or o...
# Sub-product                                                    Credit reporting
# Issue                                      Incorrect information on your report
# Sub-issue                                   Information belongs to someone else
# Consumer complaint narrative  My credit reports are inaccurate. These inaccu...
# Company public response       Company has responded to the consumer and the ...
# Company                                                           EQUIFAX, INC.
# State                                                                        FL
# ZIP code                                   Incorrect information on your report
# Tags                                                              Servicemember
# Consumer consent provided?                                 Consent not provided
# Submitted via                                                               Web
# Date sent to company                                              EQUIFAX, INC.
# Company response to consumer                            Closed with explanation
# Timely response?                                                            Yes
# Consumer disputed?                                                           No
# Complaint ID                                                                nan
#
#                                 freq
# Date received                    498
# Product                        85881
# Sub-product                   159247
# Issue                          77611
# Sub-issue                      50652
# Consumer complaint narrative     218
# Company public response        94146
# Company                        50338
# State                          27440
# ZIP code                        6399
# Tags                           10106
# Consumer consent provided?    107692
# Submitted via                 196264
# Date sent to company            3643
# Company response to consumer  134199
# Timely response?              218265
# Consumer disputed?             26112
# Complaint ID                   13880

# %%
df.isnull().sum()
# Out:
# Date received                        0
# Product                              0
# Sub-product                      10285
# Issue                                1
# Sub-issue                        31733
# Consumer complaint narrative    169902
# Company public response         118689
# Company                           2744
# State                             5834
# ZIP code                         12071
# Tags                            209817
# Consumer consent provided?       62989
# Submitted via                     9305
# Date sent to company              4474
# Company response to consumer      5177
# Timely response?                 12006
# Consumer disputed?              204085
# Complaint ID                         0
# dtype: int64
